# %%
import time
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
import pandas as pd
import os
from datetime import datetime

BASE = "https://fpt.vn"

# Danh sách các categories muốn crawl
CATEGORIES = [
    "/tin-tuc/khuyen-mai"
]

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/100.0.0.0 Safari/537.36"
}

KEYWORDS = [
    "internet", "cáp quang", "cáp đồng", "cáp đồng trục", "ethernet", "thiết bị đầu cuối", "5g", "4g", 
    "wifi", "công nghệ", "viettel", "cố định băng rộng", "băng thông", "hạ tầng mạng", "modem", 
    "gói cước", "tcp/ip", "ipv4", "ipv6", "docsis", "pppoe", "dhcp", "truyền hình", "camera", 
    "viễn thông", "robot", "dữ liệu", "nhà mạng", "hợp tác", "dịch vụ"
]

def get_page_url(category_path, page_num):
    if page_num == 1:
        return f"{BASE}{category_path}"
    return f"{BASE}{category_path}/?page={page_num}"

def crawl_listing_page(category_path, page_num):
    """Return list of article links on one listing page."""
    url = get_page_url(category_path, page_num)
    print(f"Fetching listing page {page_num}: {url}")
    try:
        resp = requests.get(url, headers=HEADERS, verify=False, timeout=10)
        if resp.status_code != 200:
            print("Failed to fetch", url)
            return []
    except Exception as e:
        print(f"Error fetching {url}: {e}")
        return []
    
    soup = BeautifulSoup(resp.text, "html.parser")
    results = []
    for div in soup.find_all("div", class_="hotnews-item"):
        a = div.find("a")
        if not a or not a.get("href"):
            continue
        link = urljoin(BASE, a["href"])
        results.append(link)
    return results

def crawl_article(article_url, apply_keyword_filter=False):
    """Extract tiêu đề, mô tả, main-content from one article page."""
    print("   Crawling article:", article_url)
    try:
        resp = requests.get(article_url, headers=HEADERS, verify=False, timeout=10)
        if resp.status_code != 200:
            print("   Failed:", resp.status_code)
            return None
    except Exception as e:
        print(f"   Error: {e}")
        return None
    
    soup = BeautifulSoup(resp.text, "html.parser")
    
    # Tiêu đề
    title_tag = soup.find("h1", class_="toc--label-head")
    title = title_tag.get_text(strip=True) if title_tag else None
    
    # Date
    date_tag = soup.find("span", class_="public-date")
    date = date_tag.get_text(strip=True) if date_tag else None
    
    # Mô tả
    desc_tag = soup.find("div", class_="toc--sub-title")
    description = desc_tag.get_text(strip=True) if desc_tag else None

    # Chỉ filter keyword nếu được yêu cầu (cho tin-fpt)
    if apply_keyword_filter and description:
        desc_lower = description.lower()
        if not any(keyword in desc_lower for keyword in KEYWORDS):
            print("   Skipped (no keyword match).")
            return None
    
    # Main content
    body_div = soup.find("div", class_="news-detail-body")
    content_parts = []
    if body_div:
        # lấy <p>
        for p in body_div.find_all("p"):
            text = p.get_text(" ", strip=True)
            if text:
                content_parts.append(text)
        # lấy <li>
        for li in body_div.find_all("li"):
            text = li.get_text(" ", strip=True)
            if text:
                content_parts.append("• " + text)
    
    content = "\n\n".join(content_parts)
    
    return {
        "Nguồn": "FPT Strategy",
        "Tiêu đề": title,
        "Mô tả": description,
        "Ngày": date,
        "URL": article_url
    }

def crawl_category(category_path, n_pages=3, delay=1.0):
    """Crawl n pages from one category."""
    print(f"\n{'='*60}")
    print(f"CRAWLING CATEGORY: {category_path}")
    print(f"{'='*60}")
    
    # Chỉ áp dụng keyword filter cho tin-fpt
    apply_filter = (category_path == "/tin-tuc/tin-fpt")
    if apply_filter:
        print(">>> Keyword filtering ENABLED for this category")
    else:
        print(">>> Keyword filtering DISABLED for this category")
    
    articles = []
    seen = set()
    for page in range(1, n_pages + 1):
        links = crawl_listing_page(category_path, page)
        for link in links:
            if link in seen:
                continue
            seen.add(link)
            art = crawl_article(link, apply_keyword_filter=apply_filter)
            if art:
                art['category'] = category_path  # Thêm cột category để biết từ đâu
                articles.append(art)
            time.sleep(0.5)
        time.sleep(delay)
    return articles

def main():
    all_articles = []
    
    # Crawl từng category
    for category in CATEGORIES:
        category_articles = crawl_category(category, n_pages=3)
        all_articles.extend(category_articles)
    
    print(f"\n{'='*60}")
    print(f"TOTAL: Crawled {len(all_articles)} articles from {len(CATEGORIES)} categories")
    print(f"{'='*60}")

    # Convert to DataFrame
    df = pd.DataFrame(all_articles)

    # Save results with timestamp
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    output_dir = r"C:\Users\Admin\Documents\VIETTEL\2-crawl-articles\scraper\output-scraper"
    os.makedirs(output_dir, exist_ok=True)

    if not df.empty:
        # In thống kê trước khi lưu
        print("\nStatistics by category:")
        print(df['category'].value_counts())
        
        # Sắp xếp lại thứ tự cột và loại bỏ 'category' khi lưu
        df_to_save = df[['Nguồn', 'Tiêu đề', 'Mô tả', 'Ngày', 'URL']]
        
        excel_file = f"{output_dir}/fpt_strategy_{timestamp}.xlsx"
        df_to_save.to_excel(excel_file, index=False)
        print(f"\nSaved results to {excel_file}")
    else:
        print("\nNo articles crawled.")


if __name__ == "__main__":
    main()
# Out:
# ============================================================
# CRAWLING CATEGORY: /tin-tuc/tin-fpt
# ============================================================
# >>> Keyword filtering ENABLED for this category
# Fetching listing page 1: https://fpt.vn/tin-tuc/tin-fpt
#    Crawling article: https://fpt.vn/tin-tuc/ai-chuan-chat-lat-mat-song-trung-fpt-camera-dua-ai-len-san-khau-gameshow-viet-13341.html
#    Crawling article: https://fpt.vn/tin-tuc/giai-ma-speed-test-vi-sao-mot-phep-do-lai-tro-thanh-chuan-muc-chat-luong-internet-13339.html
#    Crawling article: https://fpt.vn/tin-tuc/internet-fpt-va-fpt-play-duoc-de-cu-tai-tech-award-2025-13333.html
#    Crawling article: https://fpt.vn/tin-tuc/dang-ky-internet-fpt-san-combo-du-lich-thai-lan-co-vu-sea-games-33-13330.html
#    Skipped (no keyword match).
#    Crawling article: https://fpt.vn/tin-tuc/fpt-play-phat-truc-tiep-cac-tran-u17-viet-nam-da-vong-loai-afc-u17-asian-cup-13304.html
#    Skipped (no keyword match).
#    Crawling article: https://fpt.vn/tin-tuc/fpt-play-phat-song-sea-games-thailand-2025-13302.html
#    Skipped (no keyword match).
# Fetching listing page 2: https://fpt.vn/tin-tuc/tin-fpt/?page=2
#    Crawling article: https://fpt.vn/tin-tuc/cong-bo-danh-sach-khach-hang-trung-thuong-su-kien-tuan-2-va-su-kien-dac-biet-diem-danh-ngay-qua-lien-tay-tren-hi-fpt-13295.html
#    Skipped (no keyword match).
#    Crawling article: https://fpt.vn/tin-tuc/san-diem-fgold-cuc-de-doi-qua-cuc-me-cung-fpt-13281.html
#    Skipped (no keyword match).
#    Crawling article: https://fpt.vn/tin-tuc/lan-song-kiem-chung-do-toc-do-internet-that-trong-thoi-dai-quang-cao-13278.html
#    Crawling article: https://fpt.vn/tin-tuc/fpt-duoc-de-cu-hang-muc-thuong-hieu-duoc-yeu-thich-nhat-tai-giai-thuong-van-xuan-2025-13244.html
#    Skipped (no keyword match).
#    Crawling article: https://fpt.vn/tin-tuc/hanh-trinh-fpt-ket-noi-tri-thuc-so-den-lop-hoc-vung-xa-13227.html
#    Crawling article: https://fpt.vn/tin-tuc/fpt-cung-lg-mang-cong-nghe-ket-noi-tri-thuc-cho-hoc-sinh-vung-kho-13226.html
#    Skipped (no keyword match).
# Fetching listing page 3: https://fpt.vn/tin-tuc/tin-fpt/?page=3
#    Crawling article: https://fpt.vn/tin-tuc/fpt-x-flash-chien-thang-dau-truong-danh-vong-mua-dong-2025-san-sang-cho-sea-games-33-13223.html
#    Skipped (no keyword match).
#    Crawling article: https://fpt.vn/tin-tuc/3-sieu-pham-co-trang-hoa-ngu-dang-chieu-tren-fpt-play-13221.html
#    Skipped (no keyword match).
#    Crawling article: https://fpt.vn/tin-tuc/khoe-mang-fpt-lay-ngay-100k-cuc-de-13182.html
#    Crawling article: https://fpt.vn/tin-tuc/f-safe-giai-phap-bao-ve-mang-internet-an-toan-cho-ca-gia-dinh-13164.html
#    Crawling article: https://fpt.vn/tin-tuc/cong-bo-danh-sach-10-khach-hang-trung-thuong-su-kien-20-10-diem-danh-ngay-qua-lien-tay-tren-hi-fpt-13150.html
#    Skipped (no keyword match).
#    Crawling article: https://fpt.vn/tin-tuc/loat-anime-mua-thu-2025-dang-chieu-tren-fpt-play-13137.html
#    Skipped (no keyword match).
#
# ============================================================
# CRAWLING CATEGORY: /tin-tuc/vien-thong-cong-nghe
# ============================================================
# >>> Keyword filtering DISABLED for this category
# Fetching listing page 1: https://fpt.vn/tin-tuc/vien-thong-cong-nghe
#    Crawling article: https://fpt.vn/tin-tuc/lap-camera-quy-nhon-binh-dinh-tron-goi-cho-doanh-nghiep-13361.html
#    Crawling article: https://fpt.vn/tin-tuc/dich-vu-lap-camera-di-an-binh-duong-tron-goi-cho-doanh-nghiep-13360.html
#    Crawling article: https://fpt.vn/tin-tuc/instagram-ra-mat-quicksnap-cach-locket-ngay-tren-instagram-13355.html
#    Crawling article: https://fpt.vn/tin-tuc/packet-loss-la-gi-13316.html
#    Crawling article: https://fpt.vn/tin-tuc/cloudflare-la-gi-13301.html
#    Crawling article: https://fpt.vn/tin-tuc/giai-phap-lap-wifi-khach-san-resort-hien-dai-va-toi-uu-nhat-13297.html
# Fetching listing page 2: https://fpt.vn/tin-tuc/vien-thong-cong-nghe/?page=2
#    Crawling article: https://fpt.vn/tin-tuc/lap-wifi-fpt-tai-vinh-yen-vinh-phuc-13290.html
#    Crawling article: https://fpt.vn/tin-tuc/ios-261-ra-mat-ai-ho-tro-tieng-viet-tuy-chinh-liquid-glass-13224.html
#    Crawling article: https://fpt.vn/tin-tuc/huong-dan-cach-an-ung-dung-tren-samsung-hieu-qua-don-gian-13205.html
#    Crawling article: https://fpt.vn/tin-tuc/chuyen-excel-sang-word-giu-nguyen-dinh-dang-nhanh-sieu-de-13204.html
#    Crawling article: https://fpt.vn/tin-tuc/thanh-toan-tien-wifi-viettel-13198.html
#    Crawling article: https://fpt.vn/tin-tuc/giai-phap-lap-camera-van-phong-chuyen-nghiep-gia-tot-tu-fpt-13163.html
# Fetching listing page 3: https://fpt.vn/tin-tuc/vien-thong-cong-nghe/?page=3
#    Crawling article: https://fpt.vn/tin-tuc/phan-mem-ai-13162.html
#    Crawling article: https://fpt.vn/tin-tuc/cong-cu-slide-ai-13154.html
#    Crawling article: https://fpt.vn/tin-tuc/phan-mem-ve-3d-13148.html
#    Crawling article: https://fpt.vn/tin-tuc/cach-dat-mat-khau-may-tinh-win-11-13108.html
#    Crawling article: https://fpt.vn/tin-tuc/fpt-ra-mat-ung-dung-fpt-life-mot-cham-mo-tron-tien-nghi-cho-gia-dinh-viet-13104.html
#    Crawling article: https://fpt.vn/tin-tuc/lap-camera-doanh-nghiep-dong-nai-tai-fpt-uy-tin-tron-goi-13099.html
#
# ============================================================
# CRAWLING CATEGORY: /tin-tuc/khuyen-mai
# ============================================================
# >>> Keyword filtering DISABLED for this category
# Fetching listing page 1: https://fpt.vn/tin-tuc/khuyen-mai
#    Crawling article: https://fpt.vn/tin-tuc/fpt-uu-dai-black-friday-chot-mang-rinh-cam-duy-nhat-28-11-13334.html
#    Crawling article: https://fpt.vn/tin-tuc/dang-ky-internet-fpt-san-combo-du-lich-thai-lan-co-vu-sea-games-33-13330.html
#    Crawling article: https://fpt.vn/tin-tuc/cong-bo-danh-sach-khach-hang-trung-thuong-su-kien-tuan-2-va-su-kien-dac-biet-diem-danh-ngay-qua-lien-tay-tren-hi-fpt-13295.html
#    Crawling article: https://fpt.vn/tin-tuc/san-diem-fgold-cuc-de-doi-qua-cuc-me-cung-fpt-13281.html
#    Crawling article: https://fpt.vn/tin-tuc/khoe-mang-fpt-lay-ngay-100k-cuc-de-13182.html
#    Crawling article: https://fpt.vn/tin-tuc/cong-bo-danh-sach-10-khach-hang-trung-thuong-su-kien-20-10-diem-danh-ngay-qua-lien-tay-tren-hi-fpt-13150.html
# Fetching listing page 2: https://fpt.vn/tin-tuc/khuyen-mai/?page=2
#    Crawling article: https://fpt.vn/tin-tuc/chinh-phuc-giai-thuong-len-den-23-ty-dong-khi-tham-gia-diem-danh-nhan-qua-tren-hi-fpt-13103.html
#    Crawling article: https://fpt.vn/tin-tuc/dang-ky-internet-fpt-nhan-ngay-combo-voucher-len-den-150000-dong-tu-btaskee-13073.html
#    Crawling article: https://fpt.vn/tin-tuc/1-trieu-rinh-3-combo-camera-mesh-wifi-sieu-uu-dai-tu-fpt-13064.html
#    Crawling article: https://fpt.vn/tin-tuc/dang-ky-wifi-fpt-thang-10-nhan-ngay-access-point-va-3-thang-ultra-fast-13060.html
#    Crawling article: https://fpt.vn/tin-tuc/mua-net-muot-luot-phim-free-khi-lap-internet-qua-hi-fpt-13041.html
#    Crawling article: https://fpt.vn/tin-tuc/cong-bo-danh-sach-khach-hang-trung-thuong-su-kien-tuan-4-va-su-kien-dac-biet-diem-danh-ngay-qua-lien-tay-tren-hi-fpt-12898.html
# Fetching listing page 3: https://fpt.vn/tin-tuc/khuyen-mai/?page=3
#    Crawling article: https://fpt.vn/tin-tuc/fpt-tri-an-khach-hang-than-thiet-dip-sinh-nhat-voi-nhieu-uu-dai-dac-biet-12878.html
#    Crawling article: https://fpt.vn/tin-tuc/luot-net-cang-tang-phim-svip-12803.html
#    Crawling article: https://fpt.vn/tin-tuc/nang-cap-internet-fpt-mua-back-to-school-trung-laptop-xin-so-12779.html
#    Crawling article: https://fpt.vn/tin-tuc/lap-net-trung-lap-dang-ky-lap-internet-fpt-rinh-laptop-ve-nha-12772.html
#    Crawling article: https://fpt.vn/tin-tuc/cong-bo-danh-sach-05-khach-hang-trung-thuong-su-kien-tuan-3-diem-danh-ngay-qua-lien-tay-tren-hi-fpt-12768.html
#    Crawling article: https://fpt.vn/tin-tuc/back-to-school-la-gi-fpt-uu-dai-cho-mua-back-to-school-2025-12726.html
#
# ============================================================
# TOTAL: Crawled 43 articles from 3 categories
# ============================================================
#
# Statistics by category:
# category
# /tin-tuc/vien-thong-cong-nghe    18
# /tin-tuc/khuyen-mai              18
# /tin-tuc/tin-fpt                  7
# Name: count, dtype: int64
#
# Saved results to C:\Users\Admin\Documents\VIETTEL\2-crawl-articles\scraper\output-scraper/fpt_articles_20251128_134441.xlsx
